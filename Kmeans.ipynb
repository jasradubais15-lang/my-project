# %%
from sklearn.cluster import KMeans
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("Income.csv.zip")
display(df.head())
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# 1          4356              18  United-States  <=50K
# 2          4356              40  United-States  <=50K
# 3          3900              40  United-States  <=50K
# 4          3900              40  United-States  <=50K

# %%
# Convert 'income' column to numerical values
df['income'] = df['income'].apply(lambda x: 0 if x == '<=50K' else 1)

# %%
plt.scatter(df.age,df['income'])
plt.xlabel('Age')
plt.ylabel('Income')
# Out:
# Text(0, 0.5, 'Income')

# %%
km = KMeans(n_clusters=3)
y_predicted = km.fit_predict(df[['age','income']])
y_predicted
# Out:
# array([2, 2, 2, ..., 0, 2, 1], dtype=int32)

# %%
df['cluster']=y_predicted
display(df.head())
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country  income  cluster
# 0          4356              40  United-States       0        2
# 1          4356              18  United-States       0        2
# 2          4356              40  United-States       0        2
# 3          3900              40  United-States       0        2
# 4          3900              40  United-States       0        0

# %%
km.cluster_centers_
# Out:
# array([[42.34901558,  0.3555784 ],
#        [26.13438679,  0.10591501],
#        [60.27399829,  0.31645354]])

# %%
df1 = df[df.cluster==0]
df2 = df[df.cluster==1]
df3 = df[df.cluster==2]
plt.scatter(df1.age,df1['income'],color='green')
plt.scatter(df2.age,df2['income'],color='red')
plt.scatter(df3.age,df3['income'],color='black')
plt.scatter(km.cluster_centers_[:,0],km.cluster_centers_[:,1],color='purple',marker='*',label='centroid')
plt.xlabel('Age')
plt.ylabel('Income')
plt.legend()

# %%
scaler = MinMaxScaler()
scaler.fit(df[['income']])
df['income'] = scaler.transform(df[['income']])
scaler.fit(df[['age']])
df['age'] = scaler.transform(df[['age']])

# %%
display(df.head())
# Out:
#         age workclass  fnlwgt     education  education.num marital.status  \
# 0  1.000000         ?   77053       HS-grad              9        Widowed
# 1  0.890411   Private  132870       HS-grad              9        Widowed
# 2  0.671233         ?  186061  Some-college             10        Widowed
# 3  0.506849   Private  140359       7th-8th              4       Divorced
# 4  0.328767   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country  income  cluster
# 0          4356              40  United-States     0.0        2
# 1          4356              18  United-States     0.0        2
# 2          4356              40  United-States     0.0        2
# 3          3900              40  United-States     0.0        2
# 4          3900              40  United-States     0.0        0

# %%
plt.scatter(df.age,df['income'])

# %%
km = KMeans(n_clusters=3)
y_predicted = km.fit_predict(df[['age','income']])

# %%
y_predicted
# Out:
# array([2, 2, 2, ..., 1, 2, 0], dtype=int32)

# %%
df['cluster']=y_predicted
display(df.head())
# Out:
#         age workclass  fnlwgt     education  education.num marital.status  \
# 0  1.000000         ?   77053       HS-grad              9        Widowed
# 1  0.890411   Private  132870       HS-grad              9        Widowed
# 2  0.671233         ?  186061  Some-college             10        Widowed
# 3  0.506849   Private  140359       7th-8th              4       Divorced
# 4  0.328767   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country  income  cluster
# 0          4356              40  United-States     0.0        2
# 1          4356              18  United-States     0.0        2
# 2          4356              40  United-States     0.0        2
# 3          3900              40  United-States     0.0        2
# 4          3900              40  United-States     0.0        2

# %%
df1 = df[df.cluster==0]
df2 = df[df.cluster==1]
df3 = df[df.cluster==2]
plt.scatter(df1.age,df1['income'],color='green')
plt.scatter(df2.age,df2['income'],color='red')
plt.scatter(df3.age,df3['income'],color='black')
plt.scatter(km.cluster_centers_[:,0],km.cluster_centers_[:,1],color='purple',marker='*',label='centroid')
plt.legend()

# %%
sse = []
k_rng = range(1,10)
for k in k_rng:
    km = KMeans(n_clusters=k)
    km.fit(df[['age','income']])
    sse.append(km.inertia_)
plt.xlabel('K')
plt.ylabel('Sum of squared error')
# Out:
# Text(0, 0.5, 'Sum of squared error')
